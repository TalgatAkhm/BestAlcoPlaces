# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv

df = pd.read_json('initial/markets.json', typ='frame')

# %%
df
# Out:
#                                               Address  \
# 0                  �������������� ��������, ��� 25/20
# 1                     ������������ ������, �������� 1
# 2                 ����� ������, ������� �����, ��� 11
# 3                        ����� �����, ��� 5, ������ 1
# 4     ����� ������, �������� ����, ��� 88, �������� 1
# 5   ����� ������, ���������� �����, ��� 24, ������...
# 6          ����� ˸����� ���������, ��� 30, �������� 1
# 7                          ������� �����������, ��� 1
# 8              ����������� �����, ��� 25�, �������� 1
# 9        ����� �������������� ���, ��� 17, �������� 1
# 10    �������������� �������, �������� 5�, �������� 1
# 11               ���������� �����, ��� 10, �������� 1
# 12            ������������� �����, ��� 13, �������� 1
# 13                               ������ �����, ��� 74
# 14                           ���������� �����, ��� 36
# 15                    ����������� �����, �������� �/�
# ...

# %%
df['geoData']
# Out:
# 0     {'type': 'Point', 'coordinates': [37.555417, 5...
# 1     {'type': 'Point', 'coordinates': [37.554883, 5...
# 2     {'type': 'Point', 'coordinates': [37.529546, 5...
# 3     {'type': 'Point', 'coordinates': [37.40742, 55...
# 4     {'type': 'Point', 'coordinates': [37.637058, 5...
# 5     {'type': 'Point', 'coordinates': [37.521984, 5...
# 6     {'type': 'Point', 'coordinates': [37.676861, 5...
# 7     {'type': 'Point', 'coordinates': [36.941086, 5...
# 8     {'type': 'Point', 'coordinates': [37.878632, 5...
# 9     {'type': 'Point', 'coordinates': [37.718787, 5...
# 10    {'type': 'Point', 'coordinates': [37.719471, 5...
# 11    {'type': 'Point', 'coordinates': [37.731897000...
# 12    {'type': 'Point', 'coordinates': [37.668006, 5...
# 13    {'type': 'Point', 'coordinates': [37.620375, 5...
# 14    {'type': 'Point', 'coordinates': [37.667025, 5...
# 15    {'type': 'Point', 'coordinates': [37.508853, 5...
# 16    {'type': 'Point', 'coordinates': [37.50132, 55...
# ...

# %%
a = np.array(df['geoData'].values)

# %%
a
# Out:
# array([{'type': 'Point', 'coordinates': [37.555417, 55.599169]},
#        {'type': 'Point', 'coordinates': [37.554883, 55.897109]},
#        {'type': 'Point', 'coordinates': [37.529546, 55.808488]},
#        {'type': 'Point', 'coordinates': [37.40742, 55.646096]},
#        {'type': 'Point', 'coordinates': [37.637058, 55.793346]},
#        {'type': 'Point', 'coordinates': [37.521984, 55.833476]},
#        {'type': 'Point', 'coordinates': [37.676861, 55.870152]},
#        {'type': 'Point', 'coordinates': [36.941086, 55.46347]},
#        {'type': 'Point', 'coordinates': [37.878632, 55.747698]},
#        {'type': 'Point', 'coordinates': [37.718787, 55.793149]},
#        {'type': 'Point', 'coordinates': [37.719471, 55.646725]},
#        {'type': 'Point', 'coordinates': [37.731897000000004, 55.700639]},
#        {'type': 'Point', 'coordinates': [37.668006, 55.710456]},
#        {'type': 'Point', 'coordinates': [37.620375, 55.712142]},
# ...

# %%
res = []
for dic in a:
#     print(dic['coordinates'])
    res.append({'type' : 'market', 'lat' : dic['coordinates'][1], 'lon': dic['coordinates'][0]})
res
# Out:
# [{'type': 'market', 'lat': 55.599169, 'lon': 37.555417},
#  {'type': 'market', 'lat': 55.897109, 'lon': 37.554883},
#  {'type': 'market', 'lat': 55.808488, 'lon': 37.529546},
#  {'type': 'market', 'lat': 55.646096, 'lon': 37.40742},
#  {'type': 'market', 'lat': 55.793346, 'lon': 37.637058},
#  {'type': 'market', 'lat': 55.833476, 'lon': 37.521984},
#  {'type': 'market', 'lat': 55.870152, 'lon': 37.676861},
#  {'type': 'market', 'lat': 55.46347, 'lon': 36.941086},
#  {'type': 'market', 'lat': 55.747698, 'lon': 37.878632},
#  {'type': 'market', 'lat': 55.793149, 'lon': 37.718787},
#  {'type': 'market', 'lat': 55.646725, 'lon': 37.719471},
#  {'type': 'market', 'lat': 55.700639, 'lon': 37.731897000000004},
#  {'type': 'market', 'lat': 55.710456, 'lon': 37.668006},
#  {'type': 'market', 'lat': 55.712142, 'lon': 37.620375},
#  {'type': 'market', 'lat': 55.618861, 'lon': 37.667025},
#  {'type': 'market', 'lat': 55.618151, 'lon': 37.508853},
# ...

# %%
file = open("result/markets.json", "w")

file.write(json.dumps(res))
# Out:
# 1403
