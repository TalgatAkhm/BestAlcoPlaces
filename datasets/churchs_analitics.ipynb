# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv

df = pd.read_json('initial/church.json', typ='frame')

# %%
df['geoData']
# Out:
# 0      {'type': 'Point', 'coordinates': [37.617071, 5...
# 1      {'type': 'Point', 'coordinates': [37.61783, 55...
# 2      {'type': 'Point', 'coordinates': [37.616949, 5...
# 3      {'type': 'Point', 'coordinates': [37.617476, 5...
# 4      {'type': 'Point', 'coordinates': [37.618317, 5...
# 5      {'type': 'Point', 'coordinates': [37.61623, 55...
# 6      {'type': 'Point', 'coordinates': [37.61662, 55...
# 7      {'type': 'Point', 'coordinates': [37.623196, 5...
# 8      {'type': 'Point', 'coordinates': [37.674683, 5...
# 9      {'type': 'Point', 'coordinates': [37.605538, 5...
# 10     {'type': 'Point', 'coordinates': [37.441332, 5...
# 11     {'type': 'Point', 'coordinates': [37.591746, 5...
# 12     {'type': 'Point', 'coordinates': [37.627849, 5...
# 13     {'type': 'Point', 'coordinates': [37.562028, 5...
# 14     {'type': 'Point', 'coordinates': [37.34723, 55...
# 15     {'type': 'Point', 'coordinates': [37.347311, 5...
# ...

# %%
a = np.array(df['geoData'].values)

# %%
a
# Out:
# array([{'type': 'Point', 'coordinates': [37.617071, 55.751012]},
#        {'type': 'Point', 'coordinates': [37.61783, 55.75024]},
#        {'type': 'Point', 'coordinates': [37.616949, 55.750092]},
#        {'type': 'Point', 'coordinates': [37.617476, 55.751416]},
#        {'type': 'Point', 'coordinates': [37.618317, 55.750763]},
#        {'type': 'Point', 'coordinates': [37.61623, 55.750664]},
#        {'type': 'Point', 'coordinates': [37.61662, 55.750806]},
#        {'type': 'Point', 'coordinates': [37.623196, 55.752485]},
#        {'type': 'Point', 'coordinates': [37.674683, 55.772602]},
#        {'type': 'Point', 'coordinates': [37.605538, 55.744479]},
#        {'type': 'Point', 'coordinates': [37.441332, 55.785554]},
#        {'type': 'Point', 'coordinates': [37.591746, 55.742433]},
#        {'type': 'Point', 'coordinates': [37.627849, 55.710849]},
#        {'type': 'Point', 'coordinates': [37.562028, 55.730305]},
#        {'type': 'Point', 'coordinates': [37.34723, 55.657372]},
# ...

# %%
res = []
for dic in a:
#     print(dic['coordinates'])
    res.append({'type' : 'church', 'lat' : dic['coordinates'][1], 'lon': dic['coordinates'][0]})
res
# Out:
# [{'type': 'church', 'lat': 55.751012, 'lon': 55.751012},
#  {'type': 'church', 'lat': 55.75024, 'lon': 55.75024},
#  {'type': 'church', 'lat': 55.750092, 'lon': 55.750092},
#  {'type': 'church', 'lat': 55.751416, 'lon': 55.751416},
#  {'type': 'church', 'lat': 55.750763, 'lon': 55.750763},
#  {'type': 'church', 'lat': 55.750664, 'lon': 55.750664},
#  {'type': 'church', 'lat': 55.750806, 'lon': 55.750806},
#  {'type': 'church', 'lat': 55.752485, 'lon': 55.752485},
#  {'type': 'church', 'lat': 55.772602, 'lon': 55.772602},
#  {'type': 'church', 'lat': 55.744479, 'lon': 55.744479},
#  {'type': 'church', 'lat': 55.785554, 'lon': 55.785554},
#  {'type': 'church', 'lat': 55.742433, 'lon': 55.742433},
#  {'type': 'church', 'lat': 55.710849, 'lon': 55.710849},
#  {'type': 'church', 'lat': 55.730305, 'lon': 55.730305},
#  {'type': 'church', 'lat': 55.657372, 'lon': 55.657372},
#  {'type': 'church', 'lat': 55.657423, 'lon': 55.657423},
# ...

# %%
file = open("result/church.json", "w")

file.write(json.dumps(res))
# Out:
# 31770
