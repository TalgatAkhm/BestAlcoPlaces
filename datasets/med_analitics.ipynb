# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv

df = pd.read_json('initial/med3.json', typ='frame')

# %%
df.head()
# Out:
#   AgeRestriction AmbulanceStationPhone BedSpace  \
# 0       ��������                    []      NaN
# 1            NaN                    []       90
# 2            NaN                    []      NaN
# 3            NaN                    []     1242
# 4            NaN                    []       90
#
#                                 Category ChiefGender  \
# 0  �������� ������� � ������������������     �������
# 1  �������� ������� � ������������������     �������
# 2  �������� ������� � ������������������     �������
# 3  �������� ������� � ������������������     �������
# 4  �������� ������� � ������������������     �������
#
#                          ChiefName                             ChiefPhone  \
# 0     ���-�������� ������� �������  [{'ChiefPhone': ['(495) 350-35-80']}]
# 1        ���������� ���� ���������  [{'ChiefPhone': ['(495) 212-14-80']}]
# 2  ������� ��������� �������������  [{'ChiefPhone': ['(495) 304-42-16']}]
# 3        ������� ���� ������������  [{'ChiefPhone': ['(499) 735-64-29']}]
# 4           ����� ������ ���������  [{'ChiefPhone': ['(499) 199-79-56']}]
#
#                             ChiefPosition  \
# 0                            ������� ����
# 1  ����������� ����������� �������� �����
# 2                            ������� ����
# 3                            ������� ����
# 4                            ������� ����
#
#                ClarificationWorkingHours CloseDate    ...      \
# 0                                    NaN       NaN    ...
# 1  ������ ������� ������ � 8:00 �� 20:00       NaN    ...
# 2                                    NaN       NaN    ...
# 3                                    NaN       NaN    ...
# 4                                    NaN       NaN    ...
#
#                                        ObjectAddress  \
# 0  [{'PostalCode': '109387', 'AdmArea': '���-����...
# 1  [{'PostalCode': '142144', 'AdmArea': '��������...
# 2  [{'PostalCode': '111399', 'AdmArea': '��������...
# 3  [{'PostalCode': '124489', 'AdmArea': '��������...
# 4  [{'PostalCode': '123154', 'AdmArea': '������-�...
#
#                                              OrgInfo PaidServiceInfo  \
# 0  [{'OGRN': '1027739601449', 'ChiefPosition': '�...       ���������
# 1  [{'OGRN': '1035011454741', 'ChiefPosition': '�...     �����������
# 2  [{'OGRN': '1037700233790', 'ChiefPosition': '�...     �����������
# 3  [{'OGRN': '1037739064285', 'ChiefPosition': '�...     �����������
# 4  [{'OGRN': '1037734010467', 'ChiefPosition': '�...     �����������
#
#                               PublicPhone ReopenDate  \
# 0  [{'PublicPhone': ['(495) 358-35-57']}]        NaN
# 1  [{'PublicPhone': ['(495) 120-65-48']}]        NaN
# 2  [{'PublicPhone': ['(495) 304-42-16']}]        NaN
# 3  [{'PublicPhone': ['(499) 735-64-29']}]        NaN
# 4  [{'PublicPhone': ['(495) 530-33-88']}]        NaN
#
#                                            ShortName  \
# 0                                   ���� �� � 13 ���
# 1    ���� �������� ���������� ���. ������� ���������
# 2    ���� ��� ��. �.�. ������ ���. ������� ���������
# 3  ���� ��� ��. �.�. ������������� ���. ������� �...
# 4  ���� ��� � 67 ��. �. �. ���������� ���. ������...
#
#                            Specialization  \
# 0                                     NaN
# 1  ��������������� ����������� ����������
# 2  ��������������� ����������� ����������
# 3               ��������������� ���������
# 4              �������������� �����������
#
#                                         WorkingHours  \
# 0  [{'WorkHours': '�������������', 'DayWeek': '��...
# 1  [{'WorkHours': '08:00-20:00', 'DayWeek': '����...
# 2  [{'WorkHours': '08:00-20:00', 'DayWeek': '����...
# 3  [{'WorkHours': '�������������', 'DayWeek': '��...
# 4  [{'WorkHours': '�������������', 'DayWeek': '��...
#
#                                              geoData  global_id
# 0  {'type': 'MultiPoint', 'coordinates': [[37.765...  656106471
# 1  {'type': 'MultiPoint', 'coordinates': [[37.450...  656107986
# 2  {'type': 'MultiPoint', 'coordinates': [[37.814...  656107562
# 3  {'type': 'MultiPoint', 'coordinates': [[37.231...  656106344
# 4  {'type': 'MultiPoint', 'coordinates': [[37.466...  656107495
#
# [5 rows x 26 columns]

# %%
a = np.array(df['geoData'].values)
a
# Out:
# array([{'type': 'MultiPoint', 'coordinates': [[37.765188760128, 55.68237293764], [37.770752866691, 55.683005176382], [37.772298852906, 55.682677141871], [37.767310454795, 55.682511219978], [37.766269857644, 55.682415453635], [37.765541341022, 55.68210126394], [37.771692511775, 55.683110390313], [37.768364068049, 55.682575019466], [37.76587489227, 55.682120267894], [37.767663597783, 55.682761802198], [37.76536175745, 55.682689609664], [37.768573449087, 55.683919773368], [37.769113202617, 55.684008707988]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.450696233232, 55.40098558983]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.814071598966, 55.755529806488]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.231102418641, 55.983633360719], [37.230899795594, 55.984075505604]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.466007827114, 55.77087249703]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.697690053343, 55.786926800772], [37.696718885464, 55.78729875977], [37.696739708353, 55.788572487712], [37.692010151555, 55.786808329038], [37.695373258189, 55.787550094516], [37.696484226434, 55.788108004591], [37.697755244784, 55.787567967326], [37.696702443815, 55.786805813902], [37.693090499235, 55.788657426877], [37.695717358249, 55.786863645762], [37.697464040172, 55.78693926417], [37.693010385953, 55.788162934321], [37.691913514318, 55.787733455626], [37.697572792595, 55.786678652969], [37.692684055968996, 55.786797182701], [37.69263715612, 55.78735200614], [37.697705044746, 55.788071969636], [37.696839459252, 55.787193776576]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.725573943282, 55.795287864299], [37.725058535989, 55.796120446434]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.406142151499, 55.854116114481], [37.406064580085, 55.854639449917], [37.406058806519, 55.854925441067], [37.404810751177, 55.852428160766], [37.402388868313, 55.852840627969], [37.403589300226, 55.852990398195], [37.405571131235, 55.854815950165], [37.403596863926, 55.853719008798], [37.405909214876, 55.854804866096], [37.405673267971, 55.853700784437]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.5847554511, 55.765515539702], [37.584342622541, 55.765153109666], [37.586179271216, 55.765101064888], [37.58822944291, 55.764484324437], [37.585488008599, 55.76605124837], [37.584857684265, 55.769087176653], [37.584925888485, 55.764783515975], [37.584800716007, 55.768088419387], [37.587773366086, 55.764088225895], [37.58535943006, 55.764957022113], [37.587021862303, 55.765106032325]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.518699165461, 55.846256350149], [37.517632298629, 55.847627154809], [37.531397600371, 55.827864616059], [37.518229648807, 55.846391107637], [37.531968709117, 55.828198158589], [37.532012572125, 55.827650578361], [37.531798242649, 55.828937870991], [37.518377373176, 55.846952889386], [37.532058108558, 55.827454516044]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.619745922548, 55.725571223257], [37.619736158381, 55.724800698323], [37.618873813153, 55.726705202155], [37.619078059972, 55.725835406538], [37.618622093636, 55.724927895206], [37.616546594191, 55.724965100173], [37.618973359914, 55.725429468713], [37.616440734564, 55.726129337242], [37.617931141495, 55.725739716077], [37.617193983738, 55.724261825565], [37.617836709113, 55.726076449357], [37.616691768663, 55.725301419034], [37.616265046357, 55.725275681506], [37.618986472821, 55.726267184711], [37.61722542717, 55.72527219604], [37.617726749151, 55.726618112656], [37.617973910158, 55.725388438789], [37.616273175762, 55.726640768241], [37.616468320245, 55.725660641095]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.810834601353, 55.79834551669], [37.810632546763, 55.79755097937], [37.810937101001, 55.79892183647], [37.810976322089, 55.797833982245]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.727750298606, 55.874166929414]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.703732711083, 55.759664761154], [37.70604099151, 55.75843865945], [37.705494063621, 55.758595201691], [37.706546606123, 55.758213618622]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.649445958525, 55.632458625508]]}],
#       dtype=object)

# %%
res = []
for dic in a:
#     print(dic['coordinates'])

    res.append({'type' : 'med', 'lat' : dic['coordinates'][0][1], 'lon': dic['coordinates'][0][0]})
res
# Out:
# [{'type': 'med', 'lat': 55.68237293764, 'lon': 37.765188760128},
#  {'type': 'med', 'lat': 55.40098558983, 'lon': 37.450696233232},
#  {'type': 'med', 'lat': 55.755529806488, 'lon': 37.814071598966},
#  {'type': 'med', 'lat': 55.983633360719, 'lon': 37.231102418641},
#  {'type': 'med', 'lat': 55.77087249703, 'lon': 37.466007827114},
#  {'type': 'med', 'lat': 55.786926800772, 'lon': 37.697690053343},
#  {'type': 'med', 'lat': 55.795287864299, 'lon': 37.725573943282},
#  {'type': 'med', 'lat': 55.854116114481, 'lon': 37.406142151499},
#  {'type': 'med', 'lat': 55.765515539702, 'lon': 37.5847554511},
#  {'type': 'med', 'lat': 55.846256350149, 'lon': 37.518699165461},
#  {'type': 'med', 'lat': 55.725571223257, 'lon': 37.619745922548},
#  {'type': 'med', 'lat': 55.79834551669, 'lon': 37.810834601353},
#  {'type': 'med', 'lat': 55.874166929414, 'lon': 37.727750298606},
#  {'type': 'med', 'lat': 55.759664761154, 'lon': 37.703732711083},
#  {'type': 'med', 'lat': 55.632458625508, 'lon': 37.649445958525}]

# %%
file = open("result/med.json", "w")

file.write(json.dumps(res))
# Out:
# 969
