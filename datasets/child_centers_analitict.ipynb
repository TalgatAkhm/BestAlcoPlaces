# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv

df = pd.read_json('initial/child_centers.json', typ='frame')

# %%
df
# Out:
#                                              Address  \
# 0            ����� ����������, �������� �����, ��� 9
# 1                            ��������� �����, ��� 13
# 2              ����-�������� �����, ��� 11, ������ 1
# 3                        ����� �������� �����, ��� 7
# 4              ����� �������� ���, ��� 3, �������� 1
# 5                   �������� �����, ��� 17, ������ 5
# 6                                  ����� ����, ��� 7
# 7  ����� ���������������� �������, ��� 10�, �����...
#
#                                    AdmArea  \
# 0    �������������� ���������������� �����
# 1  ������-��������� ���������������� �����
# 2             ����� ���������������� �����
# 3         ��������� ���������������� �����
# 4       ����������� ���������������� �����
# 5      ���-�������� ���������������� �����
# 6         ��������� ���������������� �����
# 7          �������� ���������������� �����
#
#                                     DimensionsSummer     DisabilityFriendly  \
# ...

# %%
a = np.array(df['geoData'].values)

# %%
a
# Out:
# array([{'type': 'Point', 'coordinates': [37.373563, 55.592108]},
#        {'type': 'Point', 'coordinates': [37.565782918856286, 55.89916551798563]},
#        {'type': 'Point', 'coordinates': [37.772926694442525, 55.63834087287876]},
#        {'type': 'Point', 'coordinates': [37.75201863392862, 55.78543362832246]},
#        {'type': 'Point', 'coordinates': [37.607665259823285, 55.76979322950064]},
#        {'type': 'Point', 'coordinates': [37.607163523501484, 55.676295071995646]},
#        {'type': 'Point', 'coordinates': [37.77738742698406, 55.74189408581016]},
#        {'type': 'Point', 'coordinates': [37.53092810667195, 55.79059590083832]}],
#       dtype=object)

# %%
res = []
for dic in a:
#     print(dic['coordinates'])
    res.append({'type' : 'child_edu', 'lat' : dic['coordinates'][1], 'lon': dic['coordinates'][0]})
res
# Out:
# [{'type': 'child_edu', 'lat': 55.592108, 'lon': 37.373563},
#  {'type': 'child_edu', 'lat': 55.89916551798563, 'lon': 37.565782918856286},
#  {'type': 'child_edu', 'lat': 55.63834087287876, 'lon': 37.772926694442525},
#  {'type': 'child_edu', 'lat': 55.78543362832246, 'lon': 37.75201863392862},
#  {'type': 'child_edu', 'lat': 55.76979322950064, 'lon': 37.607665259823285},
#  {'type': 'child_edu', 'lat': 55.676295071995646, 'lon': 37.607163523501484},
#  {'type': 'child_edu', 'lat': 55.74189408581016, 'lon': 37.77738742698406},
#  {'type': 'child_edu', 'lat': 55.79059590083832, 'lon': 37.53092810667195}]

# %%
file = open("result/child_edu.json", "w")

file.write(json.dumps(res))
# Out:
# 589
