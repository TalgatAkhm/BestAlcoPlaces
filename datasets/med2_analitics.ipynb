# %%
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv

df = pd.read_json('initial/med4.json', typ='frame')

# %%
df.head()
df.size
# Out:
# 1056

# %%
a = np.array(df['geoData'].values)
a
# Out:
# array([{'type': 'MultiPoint', 'coordinates': [[37.780396028994, 55.801347393123], [37.779932153143, 55.80195968665], [37.781129370988, 55.801700230947]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.70230426052, 55.797971755549], [37.701206228943, 55.799785694673], [37.557311634659, 55.813033750414], [37.701355998484, 55.798576510198004], [37.702072336497, 55.800475097063], [37.700484311509, 55.799435690041], [37.702709929308, 55.799480304499], [37.45539513913, 55.831549653297], [37.700881423581, 55.798359773044], [37.702550368156, 55.79768802813], [37.70088557616, 55.799173307548], [37.703289999864, 55.799089255941], [37.702171206317, 55.798630613485], [37.701029261621, 55.798986876487]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.498101516184, 55.487314648648], [37.450696233232, 55.40098558983], [37.544118162215, 55.475924116878]]},
#        {'type': 'MultiPoint', 'coordinates': [[37.181821861063, 55.31857636839]]},
# ...

# %%
res = []
for dic in a:
#     print(dic['coordinates'])

    res.append({'type' : 'med', 'lat' : dic['coordinates'][0][1], 'lon': dic['coordinates'][0][0]})
res
# Out:
# [{'type': 'med', 'lat': 55.801347393123, 'lon': 37.780396028994},
#  {'type': 'med', 'lat': 55.797971755549, 'lon': 37.70230426052},
#  {'type': 'med', 'lat': 55.487314648648, 'lon': 37.498101516184},
#  {'type': 'med', 'lat': 55.31857636839, 'lon': 37.181821861063},
#  {'type': 'med', 'lat': 55.601211923889, 'lon': 37.354176191037},
#  {'type': 'med', 'lat': 55.890632537862, 'lon': 37.532783353681},
#  {'type': 'med', 'lat': 55.686016551176, 'lon': 37.555888650475},
#  {'type': 'med', 'lat': 55.618767086128, 'lon': 37.653755998334},
#  {'type': 'med', 'lat': 55.756524494575, 'lon': 37.812159397633},
#  {'type': 'med', 'lat': 55.746909411083, 'lon': 37.647591034766},
#  {'type': 'med', 'lat': 55.722801227101, 'lon': 37.433941663184},
#  {'type': 'med', 'lat': 55.983887042176, 'lon': 37.232632033742},
#  {'type': 'med', 'lat': 55.812146197695, 'lon': 37.55398617141},
#  {'type': 'med', 'lat': 55.791024968943, 'lon': 37.740212160086},
# ...

# %%
file = open("result/med2.json", "w")

file.write(json.dumps(res))
# Out:
# 2854
